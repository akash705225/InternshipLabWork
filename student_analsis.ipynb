# %% [markdown]
# #  1. Load Dataset
# Check missing values (.isnull()).
# • Remove duplicates.
# • Inspect dataset shape & dtypes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # the task 1

# %%
df1=pd.read_csv("student-mat.csv")

# %%
df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df1
# Out:
#     school;sex;age;address;famsize;Pstatus;Medu;Fedu;Mjob;Fjob;reason;guardian;traveltime;studytime;failures;schoolsup;famsup;paid;activities;nursery;higher;internet;romantic;famrel;freetime;goout;Dalc;Walc;health;absences;G1;G2;G3
# 0    GP;"F";18;"U";"GT3";"A";4;4;"at_home";"teacher...
# 1    GP;"F";17;"U";"GT3";"T";1;1;"at_home";"other";...
# 2    GP;"F";15;"U";"LE3";"T";1;1;"at_home";"other";...
# 3    GP;"F";15;"U";"GT3";"T";4;2;"health";"services...
# 4    GP;"F";16;"U";"GT3";"T";3;3;"other";"other";"h...
# ..                                                 ...
# 390  MS;"M";20;"U";"LE3";"A";2;2;"services";"servic...
# 391  MS;"M";17;"U";"LE3";"T";3;1;"services";"servic...
# 392  MS;"M";21;"R";"GT3";"T";1;1;"other";"other";"c...
# 393  MS;"M";18;"R";"LE3";"T";3;2;"services";"other"...
# 394  MS;"M";19;"U";"LE3";"T";1;1;"other";"at_home";...
#
# [395 rows x 1 columns]

# %%
df1.head()
# Out:
#   school;sex;age;address;famsize;Pstatus;Medu;Fedu;Mjob;Fjob;reason;guardian;traveltime;studytime;failures;schoolsup;famsup;paid;activities;nursery;higher;internet;romantic;famrel;freetime;goout;Dalc;Walc;health;absences;G1;G2;G3
# 0  GP;"F";18;"U";"GT3";"A";4;4;"at_home";"teacher...
# 1  GP;"F";17;"U";"GT3";"T";1;1;"at_home";"other";...
# 2  GP;"F";15;"U";"LE3";"T";1;1;"at_home";"other";...
# 3  GP;"F";15;"U";"GT3";"T";4;2;"health";"services...
# 4  GP;"F";16;"U";"GT3";"T";3;3;"other";"other";"h...

# %% [markdown]
# 2. Explore & Clean Data

# %%
df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df2=pd.read_csv("student-mat.csv",sep=";")

# %%
df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df2.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df2.shape
# Out:
# (395, 33)

# %%
df2.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# #hander the duplicate the job

# %%
df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2=df2.drop_duplicates()

# %% [markdown]
# #  3. Analysis Questions
# # • Average final grade (G3).
# # • How many students scored above 15?
# # • Is study time correlated with performance?
# # • Which gender performs better on average?

# %% [markdown]
# # Average final grade (G3).

# %%
avg3=df2['G3'].mean()
avg3
# Out:
# 10.415189873417722

# %%
df2.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df2[["G1","G2","G3"]]
# Out:
#      G1  G2  G3
# 0     5   6   6
# 1     5   5   6
# 2     7   8  10
# 3    15  14  15
# 4     6  10  10
# ..   ..  ..  ..
# 390   9   9   9
# 391  14  16  16
# 392  10   8   7
# 393  11  12  10
# 394   8   9   9
#
# [395 rows x 3 columns]

# %%
df2[df2["G3"]>15].shape
# Out:
# (40, 33)

# %% [markdown]
# # 3. Is study time correlated with performance?
# correlation = df['studytime'].corr(df['G3'])
# print(f"Correlation between study time and final grade: {correlation:.4f}")

# %%
correlation = df2['studytime'].corr(df2['G3'])
print(f"Correlation between study time and final grade: {correlation:.4f}")
# Out:
# Correlation between study time and final grade: 0.0978

# %%
 df2['studytime']
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 390    2
# 391    1
# 392    1
# 393    1
# 394    1
# Name: studytime, Length: 395, dtype: int64

# %%
 #Group by gender ('sex') and calculate the average of the final grade ('G3')
gender_performance = df2.groupby('sex')['G3'].mean()

print("Average final grade by gender:")
print(gender_performance)

# Automatically print which gender performs better
if gender_performance['M'] > gender_performance['F']:
    print(f"\nOn average, Male students perform better ({gender_performance['M']:.2f} vs {gender_performance['F']:.2f}).")
elif gender_performance['F'] > gender_performance['M']:
    print(f"\nOn average, Female students perform better ({gender_performance['F']:.2f} vs {gender_performance['M']:.2f}).")
else:
    print(f"\nBoth genders have the same average performance ({gender_performance['M']:.2f}).")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 corr(df2['G3'])
#
# NameError: name 'corr' is not defined

# %%
gender_performance=df2.groupby('sex')['G3'].mean()

# %%
gender_performance
# Out:
# sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %%
gender_performance['M']
# Out:
# 10.914438502673796

# %%
if gender_performance['M']>gender_performance['F']:
    print("the male averge greathe than female")
else :
     print("the female averge greathe than female")
# Out:
# the male averge greathe than female

# %% [markdown]
# # 4. Visualizations
# # • Histogram of grades.
# # • Scatterplot: study time vs grades.
# # • Bar chart: male vs female average score.

# %% [markdown]
# # ### 1. Histogram of Final Grades
# We generate a histogram to analyze the distribution of the students' final grades (`G3`). This visualization helps us understand the spread of the scores, the most common grade ranges, and identify any outliers (such as students scoring a 0).

# %%
sns.set_theme(style="whitegrid")

# Create the histogram
plt.figure(figsize=(8, 5))
plt.hist(df['G3'], bins=10, color='skyblue', edgecolor='black', alpha=0.8)

# Add titles and labels
plt.title("Distribution of Final Grades (G3)", fontsize=14, fontweight='bold')
plt.xlabel("Final Grade (G3)", fontsize=12)
plt.ylabel("Number of Students (Frequency)", fontsize=12)

# Show the plot
plt.show()

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))
plt.hist(df2["G3"],bins=10,color='skyblue',edgecolor='black',alpha=0.8)
# Add tittles and Labes
plt.title("Distribution of Final grades(G3)",fontsize=14,fontweight="bold")
plt.xlabel("Final Grade (G3)",fontsize=12)
plt.ylabel("Number of StudentS (Frequency)",fontsize=12)
plt.show()

# %% [markdown]
# # 2. Scatterplot: Study Time vs Grades

# %%
# Create the scatterplot
plt.figure(figsize=(8, 5))
sns.scatterplot(x='studytime', y='G3', data=df, color='purple', s=100, alpha=0.6)

# Add titles and labels
plt.title("Relationship Between Study Time and Final Grades", fontsize=14, fontweight='bold')
plt.xlabel("Weekly Study Time Category", fontsize=12)
plt.ylabel("Final Grade (G3)", fontsize=12)

# Show the plot
plt.show()

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))
sns.scatterplot(x='studytime', y='G3', data=df2,color="red",s=100,alpha=0.6)
plt.title("relation ship the between study time and final Grades",fontsize=14,fontweight="bold")
plt.xlabel("weekly studey time category", fontsize=12)
plt.ylabel("final grade",fontsize=12)
plt.show()

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))
sns.lineplot(x='studytime', y='G3', data=df2,color="red")
plt.title("relation ship the between study time and final Grades",fontsize=14,fontweight="bold")
plt.xlabel("weekly studey time category", fontsize=12)
plt.ylabel("final grade",fontsize=12)
plt.show()

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))
sns.barplot(x='studytime', y='G3', data=df2,color="red")
plt.title("relation ship the between study time and final Grades",fontsize=14,fontweight="bold")
plt.xlabel("weekly studey time category", fontsize=12)
plt.ylabel("final grade",fontsize=12)
plt.show()

# %% [markdown]
# # • Bar chart: male vs female average score.

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))
sns.barplot(x='sex', y='G3', data=df2,color="red",errorbar=None)
plt.title("Averger final grade male vs female",fontsize=14,fontweight="bold")
plt.xlabel("male and female ", fontsize=12)
plt.ylabel("averger grade",fontsize=12)
plt.show()

# %%
avegender=df2.groupby('sex')["G3"].mean()
avegender
# Out:
# sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64
